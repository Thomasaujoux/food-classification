# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Thomas Aujoux\Documents\GitHub\food-classification\Exploratory_Data_Analysis\clean.csv')
df.head()
# Out:
#    Unnamed: 0  Code produit                              Secteur  \
# 0           0           450  Produits laitiers et desserts frais
# 1           1           450  Produits laitiers et desserts frais
# 2           2           450  Produits laitiers et desserts frais
# 3           3           450  Produits laitiers et desserts frais
# 4           4           450  Produits laitiers et desserts frais
#
#                                           Ingrédient
# 0                            lait ecreme reconstitue
# 1                                              sucre
# 2                                  fruit : framboise
# 3                                              creme
# 4  epaississants : amidon transforme de mais, gom...

# %%
df2 = df[df.Ingrédient.str.contains(":")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df2 = df[df.Ingrédient.str.contains(":")]
#
# File c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...

# %%
df2 = df
df2
# Out:
#          Unnamed: 0  Code produit                              Secteur  \
# 0                 0           450  Produits laitiers et desserts frais
# 1                 1           450  Produits laitiers et desserts frais
# 2                 2           450  Produits laitiers et desserts frais
# 3                 3           450  Produits laitiers et desserts frais
# 4                 4           450  Produits laitiers et desserts frais
# ...             ...           ...                                  ...
# 1048570     1048570         72342             Bouillons et potages_RHF
# 1048571     1048571         72342             Bouillons et potages_RHF
# 1048572     1048572         72342             Bouillons et potages_RHF
# 1048573     1048573         72342             Bouillons et potages_RHF
# 1048574     1048574         72342             Bouillons et potages_RHF
#
#                                                 Ingrédient
# ...

# %%
df2.Ingrédient[df2.Ingrédient.str.contains(":")] = df2[df2.Ingrédient.str.contains(":")].Ingrédient.str.split().map(lambda x: x[0])
# df2.Ingrédient = df2.Ingrédient[:][0]
# Out:
# C:\Users\Thomas Aujoux\AppData\Local\Temp\ipykernel_15224\3903105649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.Ingrédient[df2.Ingrédient.str.contains(":")] = df2[df2.Ingrédient.str.contains(":")].Ingrédient.str.split().map(lambda x: x[0])

# %%
df2
# Out:
#          Unnamed: 0  Code produit                              Secteur  \
# 0                 0           450  Produits laitiers et desserts frais
# 1                 1           450  Produits laitiers et desserts frais
# 2                 2           450  Produits laitiers et desserts frais
# 3                 3           450  Produits laitiers et desserts frais
# 4                 4           450  Produits laitiers et desserts frais
# ...             ...           ...                                  ...
# 1048570     1048570         72342             Bouillons et potages_RHF
# 1048571     1048571         72342             Bouillons et potages_RHF
# 1048572     1048572         72342             Bouillons et potages_RHF
# 1048573     1048573         72342             Bouillons et potages_RHF
# 1048574     1048574         72342             Bouillons et potages_RHF
#
#                       Ingrédient
# 0        lait ecreme reconstitue
# 1                          sucre
# ...

# %%
df3 = df2

# %%
df3.Ingrédient[df3.Ingrédient.str.contains('\(')] = df3[df3.Ingrédient.str.contains('\(')].Ingrédient.str.split().map(lambda x: x[0])
# Out:
# C:\Users\Thomas Aujoux\AppData\Local\Temp\ipykernel_15224\3092603757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.Ingrédient[df3.Ingrédient.str.contains('\(')] = df3[df3.Ingrédient.str.contains('\(')].Ingrédient.str.split().map(lambda x: x[0])

# %%
df3
# Out:
#          Unnamed: 0  Code produit                              Secteur  \
# 0                 0           450  Produits laitiers et desserts frais
# 1                 1           450  Produits laitiers et desserts frais
# 2                 2           450  Produits laitiers et desserts frais
# 3                 3           450  Produits laitiers et desserts frais
# 4                 4           450  Produits laitiers et desserts frais
# ...             ...           ...                                  ...
# 1048570     1048570         72342             Bouillons et potages_RHF
# 1048571     1048571         72342             Bouillons et potages_RHF
# 1048572     1048572         72342             Bouillons et potages_RHF
# 1048573     1048573         72342             Bouillons et potages_RHF
# 1048574     1048574         72342             Bouillons et potages_RHF
#
#                       Ingrédient
# 0        lait ecreme reconstitue
# 1                          sucre
# ...

# %%
df3.to_csv(r'C:\Users\Thomas Aujoux\Documents\GitHub\food-classification\Exploratory_Data_Analysis\simply_clean.csv')

# %%
df2
# Out:
#          Unnamed: 0  Code produit                              Secteur  \
# 0                 0           450  Produits laitiers et desserts frais
# 1                 1           450  Produits laitiers et desserts frais
# 2                 2           450  Produits laitiers et desserts frais
# 3                 3           450  Produits laitiers et desserts frais
# 4                 4           450  Produits laitiers et desserts frais
# ...             ...           ...                                  ...
# 1048570     1048570         72342             Bouillons et potages_RHF
# 1048571     1048571         72342             Bouillons et potages_RHF
# 1048572     1048572         72342             Bouillons et potages_RHF
# 1048573     1048573         72342             Bouillons et potages_RHF
# 1048574     1048574         72342             Bouillons et potages_RHF
#
#                                                 Ingrédient
# ...

# %%
df3 = df2[df2['Ingrédient'].apply(lambda x: isinstance(x, list))]

# %%
df3[df2['Ingrédient'].apply(lambda x: isinstance(x, list))][]
# Out:
# C:\Users\Thomas Aujoux\AppData\Local\Temp\ipykernel_15224\2598425706.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3[df2['Ingrédient'].apply(lambda x: isinstance(x, list))][0]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df2.iloc[,3]
# Out:
# pandas.core.series.Series

# %%
df2
# Out:
#          Unnamed: 0  Code produit                              Secteur  \
# 0                 0           450  Produits laitiers et desserts frais
# 1                 1           450  Produits laitiers et desserts frais
# 2                 2           450  Produits laitiers et desserts frais
# 3                 3           450  Produits laitiers et desserts frais
# 4                 4           450  Produits laitiers et desserts frais
# ...             ...           ...                                  ...
# 1048570     1048570         72342             Bouillons et potages_RHF
# 1048571     1048571         72342             Bouillons et potages_RHF
# 1048572     1048572         72342             Bouillons et potages_RHF
# 1048573     1048573         72342             Bouillons et potages_RHF
# 1048574     1048574         72342             Bouillons et potages_RHF
#
#                                                 Ingrédient
# ...

# %%
df2

# %%
df2.loc[:,"Ingrédient"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# ...

# %%
for i in range(len(df2.iloc[:,3])):
    if type(df2.iloc[i,3]) == list :
        df2.iloc[i,3] = df2.iloc[i,3][0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15224\2033933281.py in ?()
#       1 for i in range(len(df2.iloc[:,3])):
#       2     if type(df2.iloc[i,3]) == list :
# ----> 3         df2.iloc[i,3] = df2.iloc[i,3][0]
#       4
#
# c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py in ?(self, key, value)
#     845         indexer = self._get_setitem_indexer(key)
#     846         self._has_valid_setitem_indexer(key)
#     847
#     848         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849         iloc._setitem_with_indexer(indexer, value, self.name)
#
# c:\Users\Thomas Aujoux\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py in ?(self, indexer, value, name)
#    1831
#    1832         # align and set the values
# ...

# %%
df2
# Out:
#          Unnamed: 0  Code produit                              Secteur  \
# 0                 0           450  Produits laitiers et desserts frais
# 1                 1           450  Produits laitiers et desserts frais
# 2                 2           450  Produits laitiers et desserts frais
# 3                 3           450  Produits laitiers et desserts frais
# 4                 4           450  Produits laitiers et desserts frais
# ...             ...           ...                                  ...
# 1048570     1048570         72342             Bouillons et potages_RHF
# 1048571     1048571         72342             Bouillons et potages_RHF
# 1048572     1048572         72342             Bouillons et potages_RHF
# 1048573     1048573         72342             Bouillons et potages_RHF
# 1048574     1048574         72342             Bouillons et potages_RHF
#
#                                                Ingrédient
# ...

# %%
df2.iloc[0,3][0]
# Out:
# 'fruit'
